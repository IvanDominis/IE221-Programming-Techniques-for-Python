# %% [markdown]
# # Lab 4B+C(TT) 5 câu từ 11-15 ở phần cuối cùng.
# Đây là phần truyền và lấy dữ liệu

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/drive/MyDrive/IE221/salaries.csv')

# %%
df
# Out:
#       work_year experience_level employment_type                  job_title  \
# 0          2022               MI              FT  Machine Learning Engineer
# 1          2022               MI              FT  Machine Learning Engineer
# 2          2022               MI              FT             Data Scientist
# 3          2022               MI              FT             Data Scientist
# 4          2022               MI              FT             Data Scientist
# ...         ...              ...             ...                        ...
# 1327       2020               SE              FT             Data Scientist
# 1328       2021               MI              FT   Principal Data Scientist
# 1329       2020               EN              FT             Data Scientist
# 1330       2020               EN              CT      Business Data Analyst
# 1331       2021               SE              FT       Data Science Manager
#
# ...

# %% [markdown]
# # Câu 1. Vẽ biểu đồ histogram biểu diễn sự phân bố mức lương theo USD (salary_in_usd)

# %%
x = list(df['salary_in_usd'])
# Khai báo tiêu đề cho trục x
plt.hist(x)
# Khai báo tiêu đề cho trục y
plt.xlabel('salary_in_usd')
plt.show()

# %% [markdown]
# # Câu 2 . Vẽ biểu đồ histogram biểu diễn sự phân bố mức lương theo VND (salary_in_vnd).

# %%
df['salary_in_vnd'] = df['salary_in_usd'] *23459
x = list(df['salary_in_vnd'])
plt.hist(x)
# Khai báo tiêu đề cho trục x
# plt.xlabel('')
# Khai báo tiêu đề cho trục y
plt.xlabel('salary_in_vnd')
plt.show()

# %% [markdown]
# # Câu 3. Vẽ biểu đồ histogram biểu diễn sự phân bố mức độ hoàn thành công việc từ xa
# (remote_ratio) (tính theo %).

# %%
x = list(df['remote_ratio'])
plt.hist(x)
plt.xlabel('remote_ratio')
plt.show()

# %% [markdown]
# # Câu 4. Thêm cột gender (giới tính) và sau đó random cho giá trị 0 và 1, trong đó 0 đại diện cho nam giới và 1 đại diện cho nữ giới. Vẽ biểu đồ tròn biểu diễn tỉ lệ phân bố giới tính và cho biết giới tính nào chiểm tỉ lệ cao hơn.

# %%
df['gender'] = np.random.randint(0,2,df.shape[0])
df.head()
# Out:
#    work_year experience_level employment_type                  job_title  \
# 0       2022               MI              FT  Machine Learning Engineer
# 1       2022               MI              FT  Machine Learning Engineer
# 2       2022               MI              FT             Data Scientist
# 3       2022               MI              FT             Data Scientist
# 4       2022               MI              FT             Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  130000             USD         130000                 US             0
# 1   90000             USD          90000                 US             0
# 2  120000             USD         120000                 US           100
# 3  100000             USD         100000                 US           100
# 4   85000             USD          85000                 US           100
#
#   company_location company_size  salary_in_vnd  gender
# ...

# %%
from collections import Counter
gender = Counter(df['gender'])
x = list(gender.keys())
y = list(gender.values())
plt.pie(y,labels = x)
plt.legend()
plt.show()

# %% [markdown]
# # Câu 5. Vẽ biểu đồ miền biểu diễn tỉ lệ phân bố giới tính (gender) qua các năm.

# %%
work_year = df['work_year'].unique()
print(work_year)
count_men = df[df['gender'] == 0].groupby('work_year').count()
count_women = df[df['gender'] == 1].groupby('work_year').count()
x = ['Nam','Nữ']
y = np.array([count_men['gender'], count_women['gender']])
p = y / y.sum(axis=0).astype(float)  *100
l = []
for i in range(3):
  l.append(str(work_year[i]))
l = np.array(l,str)
print(l)
plt.stackplot(l,p[0],p[1],colors = ['r','g'],labels=['Nam','Nữ'])
plt.title('tỉ lệ phân bố giới tính (gender) qua các năm')
plt.legend()
plt.show()
# Out:
# [2022 2021 2020]
# ['2022' '2021' '2020']

# %% [markdown]
# # Câu 6. Vẽ biểu đồ phân tán biểu diễn mối quan hệ giữa giới tính (gender) và mức lương theo VND (salary_in_vnd). Quan sát sự phân bố và xem xét liệu rằng giữa hai đại lượng này có mối quan hệ tương quan với nhau hay không. Nếu có, hãy cho biết mối quan hệ giữa hai đại lượng này có phải là mối quan hệ tuyến tính hay không?

# %%
x = list(df['gender'])
y = list(df['salary_in_vnd'])
plt.scatter(x,y)
plt.show()

# %% [markdown]
# Mối quan hệ giữa 2 đại lượng này là không tuyến tính

# %% [markdown]
# # Câu 7. Vẽ biểu đồ phân tán biểu diễn mối quan hệ giữa ngành nghề (job_title) và mức lương theo VND (salary_in_vnd). Quan sát sự phân bố và xem xét liệu rằng giữa hai đại lượng này có mối quan hệ tương quan với nhau hay không. Nếu có, hãy cho biết mối quan hệ giữa hai đại lượng này có phải là mối quan hệ tuyến tính hay không?

# %%
x = list(df['job_title'])
y = list(df['salary_in_vnd'])
plt.scatter(x,y)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Câu 8. Vẽ biểu đồ tròn biểu diễn sự phân bố quy mô công ty (company_size)

# %%
company_size = Counter(df['company_size'])

x = list(company_size.keys())
y = list(company_size.values())
plt.pie(y,labels =x)
plt.legend()
plt.show()

# %% [markdown]
# # Câu 9. Vẽ biểu đồ cột biểu diễn sự phân bố hình thức làm việc (employment_type).

# %%
employment_type = Counter(df['employment_type'])

x = list(employment_type.keys())
y = list(employment_type.values())
plt.bar(x,y)
plt.show()

# %% [markdown]
# # Câu 10. Vẽ biểu đồ cột biểu diễn số lượng nhân sự của các ngành nghề (job_title) có liên quan đến lĩnh vực Khoa học và Kỹ thuật dữ liệu (trong tên ngành nghề có từ “Data”).

# %%
df_new = df[df['job_title'].str.contains('Data')]
# print(df_new['job_title'])
d = df_new['job_title'].unique()
print(len(d))
quantity = []
for name in d:
  t = df_new['job_title'].value_counts()[name]
  quantity.append(t)
print(quantity,len(quantity))
plt.bar(d,quantity)
plt.xticks(rotation = 90)
plt.show()
# Out:
# 42
# [344, 320, 7, 190, 4, 37, 8, 2, 1, 1, 9, 5, 12, 9, 1, 6, 5, 1, 29, 6, 8, 6, 8, 3, 1, 3, 6, 1, 7, 6, 3, 4, 2, 1, 7, 3, 3, 2, 2, 1, 1, 1] 42

# %% [markdown]
# # Câu 11. Tính trung bình mức lương theo USD (salary_in_usd) của tất cả những người được khảo sát theo từng năm. Vẽ biểu đồ đường biểu diễn sự thay đổi trung bình mức lương theo USD (salary_in_usd), từ đó đưa ra dự đoán về xu hướng thay đổi mức lương theo USD (salary_in_usd) trong tương lai.

# %%
work_year = df['work_year'].unique()
average = dict(df.groupby('work_year')['salary_in_usd'].mean())
print(average)
x = list(average.keys())
y = list(average.values())
plt.bar(x,y)
plt.xticks(work_year)
plt.show()
# Out:
# {2020: 92644.41333333333, 2021: 97400.85087719298, 2022: 131369.60155490768}

# %% [markdown]
# # Câu 12. Tính trung bình tỉ lệ hoàn thành công việc từ xa (remote_ratio) (tính theo %) của tất cả những người được khảo sát theo từng năm. Vẽ biểu đồ đường biểu diễn sự thay đổi tỉ lệ hoàn thành công việc từ xa (remote_ratio), từ đó đưa ra dự đoán về xu hướng thay đổi tỉ lệ hoàn thành công việc từ xa (remote_ratio) trong tương lai.

# %%
work_year = df['work_year'].unique()
remote_ratio = df.groupby('work_year')['remote_ratio'].mean()
print(remote_ratio)
plt.plot(work_year,list(remote_ratio))
plt.xticks(work_year)
plt.show()
# Out:
# work_year
# 2020    66.000000
# 2021    69.078947
# 2022    62.536443
# Name: remote_ratio, dtype: float64

# %% [markdown]
# Tỉ lệ hoàn thành công việc (remote ratio) qua 3 năm có thể dễ dàng thấy từ năm 2020-2021 có dấu hiệu tăng khá mạnh nhưng đến năm 2022 lại giảm đi bằng một nửa số lần tăng. Có thể trong tương lai con số sẽ tăng lên lại như giá trị ở 2021.

# %% [markdown]
# # Câu 13. Tính trung bình mức lương theo USD (salary_in_usd) của 500 người đầu tiên trong bộ dữ liệu, sau đó thống kê số lượng nhân sự trong số 500 người này theo hai nhóm sau:
# • “Muc luong thap”: Những người có mức lương thấp hơn mức trung bình.
#
# • “Muc luong cao”: Những người có mức lương từ mức trung bình trở lên.
#
# Vẽ biểu đồ tròn biểu diễn sự phân bố mức lương và rút ra nhận xét

# %%
df_first = df.head(500)
mean_salary = df_first['salary_in_usd'].mean()
print(mean_salary)
mean_of_salary = []
for salary in df_first['salary_in_usd']:
  if salary < mean_salary:
    mean_of_salary.append('Muc luong thap')
  else: mean_of_salary.append('Muc luong cao')
df_first['quality_of_salary'] = mean_of_salary
# Out:
# 134229.31
# <ipython-input-59-d1ad1baf3be5>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_first['quality_of_salary'] = mean_of_salary

# %%
df_first.head()
# Out:
#    work_year experience_level employment_type                  job_title  \
# 0       2022               MI              FT  Machine Learning Engineer
# 1       2022               MI              FT  Machine Learning Engineer
# 2       2022               MI              FT             Data Scientist
# 3       2022               MI              FT             Data Scientist
# 4       2022               MI              FT             Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  130000             USD         130000                 US             0
# 1   90000             USD          90000                 US             0
# 2  120000             USD         120000                 US           100
# 3  100000             USD         100000                 US           100
# 4   85000             USD          85000                 US           100
#
#   company_location company_size  salary_in_vnd  gender quality_of_salary
# ...

# %%
salary_col = Counter(df_first['quality_of_salary'])
x = list(salary_col.keys())
y = list(salary_col.values())
plt.pie(y,labels=x)
plt.legend(gender)
plt.show()

# %% [markdown]
# Mức lương

# %% [markdown]
# # Câu 14. Thống kê tỉ lệ hoàn thành công việc từ xa (remote_ratio) (tính theo %) của 500 người đầu tiên trong bộ dữ liệu theo hai nhóm sau:
# • “Lam viec tu xa khong hieu qua”: Những người có tỉ lệ hoàn thành công việc từ xa
# nhỏ hơn 50%.
#
# • “Lam viec tu xa hieu qua”: Những người có tỉ lệ hoàn thành công việc từ xa từ 50%
# trở lên.
#
# Vẽ biểu đồ tròn biểu diễn sự phân bố tỉ lệ hoàn thành công việc từ xa và rút ra nhận xét.

# %%
df_first = df.head(500)
type = []
for remote in df_first['remote_ratio']:
  if remote < 50:
    type.append('Lam viec tu xa khong hieu qua')
  else: type.append('Lam viec tu xa hieu qua')
df_first['type'] = type
# Out:
# <ipython-input-57-38c0f61daf78>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_first['type'] = type

# %%
df_first.head()
# Out:
#    work_year experience_level employment_type                  job_title  \
# 0       2022               MI              FT  Machine Learning Engineer
# 1       2022               MI              FT  Machine Learning Engineer
# 2       2022               MI              FT             Data Scientist
# 3       2022               MI              FT             Data Scientist
# 4       2022               MI              FT             Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  130000             USD         130000                 US             0
# 1   90000             USD          90000                 US             0
# 2  120000             USD         120000                 US           100
# 3  100000             USD         100000                 US           100
# 4   85000             USD          85000                 US           100
#
#   company_location company_size  salary_in_vnd  gender  \
# ...

# %%
type_col = Counter(df_first['type'])
x = list(type_col.keys())
y = list(type_col.values())
plt.pie(y,labels=x)
plt.legend(gender)
plt.show()

# %% [markdown]
# # Câu 15. Vẽ biểu đồ cột biểu diễn số lượng công ty đặt tại mỗi quốc gia (company_location).

# %%
company_location = dict(df.groupby(['company_location'])['company_location'].count())
company_loc = df['company_location'].unique()
print(company_location)
x = list(company_location.keys())
y = list(company_location.values())
plt.figure(figsize = (20,5))
plt.bar(x,y)
# plt.xticks(rotation = 90)
plt.show()
# Out:
# {'AE': 3, 'AL': 1, 'AR': 1, 'AS': 2, 'AT': 5, 'AU': 9, 'BE': 4, 'BO': 1, 'BR': 14, 'CA': 39, 'CH': 2, 'CL': 1, 'CN': 2, 'CO': 1, 'CZ': 3, 'DE': 35, 'DK': 4, 'DZ': 1, 'EE': 1, 'EG': 1, 'ES': 28, 'FI': 1, 'FR': 20, 'GB': 87, 'GR': 13, 'HN': 1, 'HR': 1, 'HU': 1, 'ID': 2, 'IE': 1, 'IL': 1, 'IN': 36, 'IQ': 1, 'IR': 1, 'IT': 2, 'JP': 6, 'KE': 1, 'LU': 3, 'MD': 1, 'MT': 1, 'MX': 4, 'MY': 1, 'NG': 3, 'NL': 9, 'NZ': 1, 'PH': 1, 'PK': 3, 'PL': 4, 'PR': 4, 'PT': 9, 'RO': 1, 'RU': 2, 'SG': 3, 'SI': 2, 'TH': 1, 'TR': 5, 'UA': 1, 'US': 939, 'VN': 1}
