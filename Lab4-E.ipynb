# %%
from sympy import *
import math

# %% [markdown]
# # Câu 1.1. Tính giá trị của các biểu thức sau:

# %% [markdown]
# a. 𝑆1 = 𝑥^2 + 2𝑥 + 5 tại 𝑥 = 5

# %%
from sympy.abc import x
s1 = x**2+2*x+5
s1.subs(x,5)
# Out:
# 40

# %%
exp = "x**2+2*x+5"
x, y = symbols('x y')
print(s1.subs(x,5))
# Out:
# x**2 + 2*x + 5
# 40

# %% [markdown]
# b.𝑆2 = sin𝑥 tại 𝑥 = pi

# %%
exp = sin(x)
print(exp) 
print(exp.subs(x,pi))
# Out:
# sin(x)
# 0

# %% [markdown]
# c. 𝑆3 = 𝜋𝑟^2 tại 𝑟 = 5

# %%
from sympy.abc import r
S3 = pi*r**2
S3.subs(r,5)
# Out:
# 25*pi

# %%
S5 = log(x)**2
S5.subs(x,E)
# Out:
# 1

# %%
S6 = 1/(x**3-x+1)
S6.subs(x,5)
# Out:
# 1/121

# %%
from sympy.abc import a,b
S7 = a/b
S7.subs({a:100,b:3})
# Out:
# 100/3

# %%
S9 = sin(x)/x + 0.5*cos(x) - 2/(tan(x))**2
S9.subs(x,pi/3)
# Out:
# -0.416666666666667 + 3*sqrt(3)/(2*pi)

# %%
S10 = (1/3)*x**2*y + x*y**2 - x*y + 0.5*x*y**2 - 5*x*y - (1/3)*x**2*y
S10.subs({x:1/2,y:1})
# Out:
# -2.25000000000000

# %% [markdown]
# # Câu 1.2. Khai triển các đa thức sau:

# %%
A1 = (x+y)**3
A1.expand()
# Out:
# x**3 + 3*x**2*y + 3*x*y**2 + y**3

# %%
A3 = (x+1)*(x-2) - (x-1)*x
A3.expand()
# Out:
# -2

# %%
A4 = (x-2*y)*(3*x*y+5*y**2+x)
A4.expand()
# Out:
# 3*x**2*y + x**2 - x*y**2 - 2*x*y - 10*y**3

# %%
A5 = (2/3)*x*y*(2*x**2*y - 3*x*y + y**2)
A5.expand()
# Out:
# 1.33333333333333*x**3*y**2 - 2.0*x**2*y**2 + 0.666666666666667*x*y**3

# %%
A9 = 12*x**2*y**2*(2*x+y)*(2*x-y)
A9.expand()
# Out:
# 48*x**4*y**2 - 12*x**2*y**4

# %% [markdown]
# # Câu 1.3. Phân tích các đa thức sau thành nhân tử:

# %%
B1 = x**3 - 6*x**2*y + 12*x*y - 8*y**3
B1.factor()
# Out:
# x**3 - 6*x**2*y + 12*x*y - 8*y**3

# %%
from sympy.abc import m,n
B3 = m*n**3 - 1 + m + n*2
B3.factor()
# Out:
# m*n**3 + m + 2*n - 1

# %%
B4 = -x + 6*x**2*y -12*x*y + 2
B4.factor()
# Out:
# (x - 2)*(6*x*y - 1)

# %%
B5 = x**2 - 9 + (2*x+7)*(3-x)
B5.factor()
# Out:
# -(x - 3)*(x + 4)

# %%
B7 = x**2 + 4*x - y**2 + 3
B7.factor()
# Out:
# x**2 + 4*x - y**2 + 3

# %%
B9 = a*x - b*x - a**2 + 2*a*b - b**2
B9.factor()
# Out:
# (a - b)*(-a + b + x)

# %%
B10 = x**10 + x**5 + 1
B10.factor()
# Out:
# (x**2 + x + 1)*(x**8 - x**7 + x**5 - x**4 + x**3 - x + 1)

# %% [markdown]
# # Câu 1.4: Giải các phương trình đại số sau trên tập số thực

# %% [markdown]
# 𝐚. (𝑥^2 − 𝑥 − 2)√(𝑥 + 1) = 0

# %%
from sympy.abc import x
solveset(Eq((x**2-x-2)*(x+1)**0.5,0),x)
# Out:
# Union(ConditionSet(x, Eq((x + 1)**0.5, 0), Complexes), {2})

# %%
solve((x**2-x-2)*(x+1)**0.5,x)
# Out:
# [-1.00000000000000, 2.00000000000000]

# %% [markdown]
# 𝐜. √(𝑥^2 − 2𝑥) = √(2𝑥 − 𝑥^2)

# %%
solve((x**2-2*x)**0.5 - (2*x-x**2)**0.5,x)
# Out:
# [0.0, 2.00000000000000]

# %% [markdown]
# 𝐝. 11/(𝑥^2) − 25/(𝑥 + 5)^2 = 1

# %%
solve((11/x**2 - 25/(x+5)**2), x)
# Out:
# [55/14 - 25*sqrt(11)/14, 55/14 + 25*sqrt(11)/14]

# %% [markdown]
# 𝐟. 𝑥(𝑥^2 − 1) = √2

# %%
solve( x*(x**2-1)- 2**0.5,x)
# Out:
# [1.41421356237310,
#  -0.707106781186548 - 0.707106781186549*I,
#  -0.707106781186548 + 0.707106781186549*I]

# %% [markdown]
# # Câu 1.5: Xác định phần thực và phần ảo của kết quả các phép tính số phức sau:

# %% [markdown]
# 𝐚. 1/(2-3i)

# %%
exp = 1/(2-3*I)
print('Phần thực:', re(exp))
print('Phần ảo:', im(exp))
# Out:
# Phần thực: 2/13
# Phần ảo: 3/13

# %% [markdown]
# b. 1/(1/2 - ((3**0.5)/2) * i)

# %%
exp = 1/(1/2 - ((3**0.5)/2)*I)
print('Phần thực:', re(exp))
print('Phần ảo:', im(exp))
# Out:
# Phần thực: 0.500000000000000
# Phần ảo: 0.866025403784439

# %% [markdown]
# c. (3-2i)/i

# %%
exp = (3-2*I)/I
print('Phần thực:', re(exp))
print('Phần ảo:', im(exp))
# Out:
# Phần thực: -2
# Phần ảo: -3

# %% [markdown]
# d. (3-4i)/(4-i)

# %%
exp = (3-4*I)/(4-I)
print('Phần thực:', re(exp))
print('Phần ảo:', im(exp))
# Out:
# Phần thực: 16/17
# Phần ảo: -13/17

# %% [markdown]
# # Câu 1.6:Tính giá trị của các biểu thức logic sau:

# %% [markdown]
# 𝐚. 𝑥 AND 𝑦 tại 𝑥 = True và 𝑦 = True

# %%
from sympy.abc import x, y
x = True
y = True
And(x,y)
# Out:
# True

# %% [markdown]
# 𝐛.NOT(𝑥 AND 𝑦) tại 𝑥 = True và 𝑦 = False

# %%
x = True
y = False
Not(And(x,y))
# Out:
# True

# %% [markdown]
# 𝐜. 𝑎 XOR 𝑏 XOR 𝑐 XOR 𝑑 XOR 𝑒 tại 𝑎 = True, 𝑏 = False, 𝑐 = True, 𝑑 = True và 𝑒 = False

# %%
from sympy.abc import c,d,e
a = c = d = True
b = e =False
Xor(a,b,c,d,e)
# Out:
# True

# %% [markdown]
# 𝐝. NOT(𝑎 AND 𝑏 AND NOT(𝑐 OR 𝑑)) tại 𝑎 = True, 𝑏 = False, 𝑐 = True và 𝑑 = False

# %%
a = c = True
b = d = False
Not(And(a,b,Not(Or(c,d))))
# Out:
# True

# %% [markdown]
# # Câu 2.1: Tính các giới hạn sau:

# %% [markdown]
# 𝐚. 𝐿1 = lim
# 𝑥→0
# (𝑥^
# 3 − cos𝑥 + 1) /
# (𝑥^
# 4 + 𝑥^
# 2)

# %%
from sympy.abc import x
exp = (x**3 - cos(x) + 1) / (x**4 + x**2)
print('Limit of the expression tends to:',limit(exp,x,0))
# Out:
# Limit of the expression tends to: 1/2

# %% [markdown]
# 𝐛. 𝐿2 = lim
# 𝑥→0
# ln(1 − 2𝑥(sin𝑥)^2)/(
# sin(𝑥^
# 2).tanx)

# %%
exp = ln(1-2*x*sin(x)**2)/(sin(x**2)*tan(x))
print('Limit of the expression tends to:',limit(exp,x,0))
# Out:
# Limit of the expression tends to: -2

# %% [markdown]
# 𝐝. 𝐿4 = lim
# 𝑥→+∞
# (𝑥
# ^3 − cos 𝑥 + 1)/
# (3𝑥^
# 3 + 2x)

# %%
exp = (x**3 - cos(x) + 1) / (3*x**3+2*x)
print('Limit of the expression tends to:',limit(exp,x,oo))
# Out:
# Limit of the expression tends to: 1/3

# %% [markdown]
# 𝐠. 𝐿7 = lim
# 𝑥→0
# (sin
# (2𝑥)^2/(
# 1 − cosx)

# %%
exp = (sin(2*x)**2)/(1-cos(x))
print('Limit of the expression tends to:',limit(exp,x,0))
# Out:
# Limit of the expression tends to: 8

# %% [markdown]
# # Câu 2.2: Tính đạo hàm cấp 1 của các hàm số sau:

# %% [markdown]
# 𝐚. 𝐹1
# (𝑥) = 𝑥 arcsin(𝑥^
# 2 + 1)

# %%
f1 = x*asin(x**2+1)
diff(f1,x,1)
# Out:
# 2*x**2/sqrt(1 - (x**2 + 1)**2) + asin(x**2 + 1)

# %% [markdown]
# 𝐛. 𝐹2
# (𝑥) = √(1 + 𝑥^
# 2)

# %%
f2 = (1+ x**2)**0.5
diff(f2,x,1)
# Out:
# 1.0*x/(x**2 + 1)**0.5

# %% [markdown]
# 𝐜. 𝐹3
# (𝑥) = (2𝑥**
# 2 + 1)**
# arctan x

# %%
f3 = (2*x*2 + 1)**atan(x)
diff(f3,x,1)
# Out:
# (4*x + 1)**atan(x)*(log(4*x + 1)/(x**2 + 1) + 4*atan(x)/(4*x + 1))

# %% [markdown]
# 𝐝. 𝐹4
# (𝑥) = (2𝑥 + 3) + cos x

# %%
f4 = (2*x+3) + cos(x)
diff(f4,x,1)
# Out:
# 2 - sin(x)

# %% [markdown]
# # Câu 2.3: Tìm các nguyên hàm sau:

# %% [markdown]
# 𝐚.𝐼1 = ∫(𝑥^
# 2 + 𝑥 + 1)dx

# %%
l1 = x**2 + x + 1
integrate(l1,x)
# Out:
# x**3/3 + x**2/2 + x

# %% [markdown]
# 𝐛.𝐼2 = ∫(sin𝑥.tan𝑥)dx

# %%
l2 = sin(x)*tan(x)
integrate(l2,x)
# Out:
# -log(sin(x) - 1)/2 + log(sin(x) + 1)/2 - sin(x)

# %% [markdown]
# 𝐜.𝐼3 = ∫
# 1/(
# 4 − 𝑥^
# 2)
# d𝑥

# %%
l3 = 1/(4-x**2)
integrate(l3,x)
# Out:
# -log(x - 2)/4 + log(x + 2)/4

# %% [markdown]
# 𝐝.𝐼4 = ∫
# 1
# /(𝑥^
# 2 − 𝑥 − 6)
# dx

# %%
l4 = 1/(x**2-x-6)
integrate(l4,x)
# Out:
# log(x - 3)/5 - log(x + 2)/5

# %% [markdown]
# # Câu 2.4: Tính các tích phân sau:

# %% [markdown]
# 𝐚.𝐼1 = ∫
# 1/(
# 𝑥
# ^2 − 2𝑥 + 5)
# dx

# %%
l1 = 1/(x**2-2*x+5)
integrate(l1,(x,1,3))
# Out:
# pi/8

# %% [markdown]
# 𝐛.𝐼2 = ∫ 𝑥cos𝑥dx

# %%
l2 = x*cos(x)
integrate(l2,(x,0,pi))
# Out:
# -2

# %% [markdown]
# 𝐝.𝐼4 = ∫ (sin𝑥)^8dx

# %%
l4 = sin(x)**8
integrate(l4,(x,0,pi/2))
# Out:
# 35*pi/256

# %% [markdown]
# 𝐠.𝐼7 = ∫
# 1/
# (1 − 𝑥)^
# 2
# dx

# %%
l7 = 1/(1-x)**2
integrate(l7,(x,-oo,0))
# Out:
# 1

# %% [markdown]
# # Câu 2.5: Giải các phương trình vi phân sau:

# %% [markdown]
# 𝐚. 𝑦
# ′ = 2𝑥√(𝑥^
# 2 + 16)

# %%
from sympy.abc import x
y = Function('y')
eq = Eq(y(x).diff(x) - 2*x*(x**2+16)**0.5,0)
dsolve(eq)
# Out:
# Eq(y(x), C1 + 2.66666666666667*x**2*sqrt(0.0625*x**2 + 1.0) + 42.6666666666667*sqrt(0.0625*x**2 + 1.0))

# %%
x = Symbol('x')
y = Function('y')(x)
eq = Eq(y.diff(x) - 2 * x * sqrt(x**2 + 16), 0)
sol = dsolve(eq)
print(sol)
# Out:
# Eq(y(x), C1 + 2*x**2*sqrt(x**2 + 16)/3 + 32*sqrt(x**2 + 16)/3)

# %% [markdown]
# 𝐛. 𝑦
# ′ = 2𝑥√y

# %%
y = Function('y')(x)
eq = Eq(y.diff(x)- 2*x*sqrt(y),0)
dsolve(eq)
# Out:
# Eq(y(x), C1**2/4 + C1*x**2/2 + x**4/4)

# %%
x = Symbol('x')
y = Function('y')(x)
eq = Eq(y.diff(x) - 2 * x * sqrt(y), 0)
sol = dsolve(eq)
print(sol)
# Out:
# Eq(y(x), C1**2/4 + C1*x**2/2 + x**4/4)

# %% [markdown]
# 𝐜. 𝑦
# ′ = 3𝑦 − 𝑥 + 6𝑥^
# 2

# %%
y = Function('y')(x)
eq = Eq(y.diff(x)-3*y+x-6*x**2,0)
dsolve(eq)
# Out:
# Eq(y(x), C1*exp(3*x) - 2*x**2 - x - 1/3)

# %%
x = Symbol('x')
y = Function('y')(x)
eq = Eq(y.diff(x) - 3 * y + x - 6 * x**2, 0)
sol = dsolve(eq)
print(sol)
# Out:
# Eq(y(x), C1*exp(3*x) - 2*x**2 - x - 1/3)

# %% [markdown]
# 𝐝. 𝑦
# ′ − 𝑦 sin 𝑥 = sin 𝑥 . cos x

# %%
y = Function('y')(x)
eq = Eq(y.diff(x)-y*sin(x),sin(x)*cos(x))
dsolve(eq)
# Out:
# Eq(y(x), C1*exp(-cos(x)) - cos(x) + 1)

# %%
x = Symbol('x')
y = Function('y')(x)
eq = Eq(y.diff(x) - y * sin(x), sin(x) * cos(x))
sol = dsolve(eq)
print(sol)
# Out:
# Eq(y(x), C1*exp(-cos(x)) - cos(x) + 1)

# %% [markdown]
# # Câu 3: Thu gọn các biểu thức lượng giác sau:

# %% [markdown]
# a. 𝑇1 = sin 𝑥/cos 𝑥

# %%
from sympy.abc import x
trigsimp(sin(x)/cos(x))
# Out:
# tan(x)

# %% [markdown]
# b. 𝑇2 = tan 𝑥 cos 𝑥

# %%
trigsimp(tan(x)*cos(x))
# Out:
# sin(x)

# %% [markdown]
# c. 𝑇3 = (tan^2𝑥 + 1)/(1 + cot^2𝑥)

# %%
trigsimp((tan(x)**2+1)/(1+cot(x)**2))
# Out:
# tan(x)**2

# %% [markdown]
# d. 𝑇4 = sin^2𝑥 + cos^2x

# %%
trigsimp((sin(x)**2)+cos(x)**2)
# Out:
# 1
